# %% [markdown]
# **Úkol 9 - Teplota ve městech**

# %%
import pandas

# %%
teploty = pandas.read_csv('temperature.csv')

# %% [markdown]
# * Prvních pár řádků

# %%
teploty.head()
# Out:
#    Region  Country     City  Day  AvgTemperature
# 0  Africa  Algeria  Algiers    1            62.0
# 1  Africa  Algeria  Algiers    2            62.2
# 2  Africa  Algeria  Algiers    3            65.7
# 3  Africa  Algeria  Algiers    4            69.8
# 4  Africa  Algeria  Algiers    5            63.8

# %% [markdown]
# * Posledních pár řádků

# %%
teploty.tail()
# Out:
#              Region Country      City  Day  AvgTemperature
# 8785  North America      US  Cheyenne   26            51.7
# 8786  North America      US  Cheyenne   27            55.5
# 8787  North America      US  Cheyenne   28            38.5
# 8788  North America      US  Cheyenne   29            36.8
# 8789  North America      US  Cheyenne   30            36.9

# %% [markdown]
# * Data v Praze

# %%
praha = teploty[teploty["City"]=="Prague"]

# %%
praha
# Out:
#       Region         Country    City  Day  AvgTemperature
# 2100  Europe  Czech Republic  Prague    1            43.5
# 2101  Europe  Czech Republic  Prague    2            48.5
# 2102  Europe  Czech Republic  Prague    3            44.4
# 2103  Europe  Czech Republic  Prague    4            39.7
# 2104  Europe  Czech Republic  Prague    5            40.6
# 2105  Europe  Czech Republic  Prague    6            42.3
# 2106  Europe  Czech Republic  Prague    7            43.5
# 2107  Europe  Czech Republic  Prague    8            41.4
# 2108  Europe  Czech Republic  Prague    9            43.8
# 2109  Europe  Czech Republic  Prague   10            43.0
# 2110  Europe  Czech Republic  Prague   11            39.5
# 2111  Europe  Czech Republic  Prague   12            36.7
# 2112  Europe  Czech Republic  Prague   13            35.8
# 2113  Europe  Czech Republic  Prague   14            35.5
# 2114  Europe  Czech Republic  Prague   15            39.1
# ...

# %% [markdown]
#  - data jsou ve Fahrnheitech

# %% [markdown]
# * Teplota > 80

# %%
vysoketeploty = teploty[teploty["AvgTemperature"] > 80]

# %%
vysoketeploty
# Out:
#              Region Country             City  Day  AvgTemperature
# 30           Africa   Benin          Cotonou    1            81.7
# 31           Africa   Benin          Cotonou    2            81.8
# 32           Africa   Benin          Cotonou    3            83.6
# 33           Africa   Benin          Cotonou    4            83.4
# 34           Africa   Benin          Cotonou    5            80.3
# ...             ...     ...              ...  ...             ...
# 8011  North America      US      Brownsville    2            80.8
# 8012  North America      US      Brownsville    3            81.1
# 8015  North America      US      Brownsville    6            80.5
# 8042  North America      US   Corpus Christi    3            80.2
# 8074  North America      US  Dallas Ft Worth    5            80.1
#
# [722 rows x 5 columns]

# %% [markdown]
# * Teploty > 60 Evropa

# %%
vysokeevropa =teploty [(teploty["AvgTemperature"]>60)& (teploty["Region"] == "Europe")]

# %%
vysokeevropa
# Out:
#       Region   Country       City  Day  AvgTemperature
# 1932  Europe   Albania     Tirana   13            60.3
# 2402  Europe     Italy       Rome    3            62.2
# 2404  Europe     Italy       Rome    5            60.4
# 2580  Europe  Portugal     Lisbon    1            62.5
# 2581  Europe  Portugal     Lisbon    2            63.2
# 2582  Europe  Portugal     Lisbon    3            61.1
# 2583  Europe  Portugal     Lisbon    4            61.6
# 2602  Europe  Portugal     Lisbon   23            64.2
# 2603  Europe  Portugal     Lisbon   24            62.6
# 2701  Europe     Spain  Barcelona    2            63.8
# 2702  Europe     Spain  Barcelona    3            63.1
# 2703  Europe     Spain  Barcelona    4            63.5
# 2704  Europe     Spain  Barcelona    5            61.6
# 2730  Europe     Spain     Bilbao    1            62.9
# 2731  Europe     Spain     Bilbao    2            66.3
# 2732  Europe     Spain     Bilbao    3            63.8
# ...

# %% [markdown]
# * Extremni hodnoty

# %%
extremni = teploty[(teploty["AvgTemperature"]< -20) | (teploty["AvgTemperature"]> 80)]

# %%
extremni
# Out:
#              Region Country             City  Day  AvgTemperature
# 30           Africa   Benin          Cotonou    1            81.7
# 31           Africa   Benin          Cotonou    2            81.8
# 32           Africa   Benin          Cotonou    3            83.6
# 33           Africa   Benin          Cotonou    4            83.4
# 34           Africa   Benin          Cotonou    5            80.3
# ...             ...     ...              ...  ...             ...
# 8011  North America      US      Brownsville    2            80.8
# 8012  North America      US      Brownsville    3            81.1
# 8015  North America      US      Brownsville    6            80.5
# 8042  North America      US   Corpus Christi    3            80.2
# 8074  North America      US  Dallas Ft Worth    5            80.1
#
# [772 rows x 5 columns]

# %% [markdown]
# * Bonus

# %%
pip install pytemperature
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pytemperature

# %%
teploty["AvgTempCels"] = pytemperature.f2c(teploty["AvgTemperature"])

# %%
teploty.head()
# Out:
#    Region  Country     City  Day  AvgTemperature  AvgTempCels
# 0  Africa  Algeria  Algiers    1            62.0        16.67
# 1  Africa  Algeria  Algiers    2            62.2        16.78
# 2  Africa  Algeria  Algiers    3            65.7        18.72
# 3  Africa  Algeria  Algiers    4            69.8        21.00
# 4  Africa  Algeria  Algiers    5            63.8        17.67

# %%
teploty["AvgTempCels2"] = ((teploty["AvgTemperature"])-32)* 0.5556

# %%
teploty.head()
# Out:
#    Region  Country     City  Day  AvgTemperature  AvgTempCels  AvgTempCels2
# 0  Africa  Algeria  Algiers    1            62.0        16.67      16.66800
# 1  Africa  Algeria  Algiers    2            62.2        16.78      16.77912
# 2  Africa  Algeria  Algiers    3            65.7        18.72      18.72372
# 3  Africa  Algeria  Algiers    4            69.8        21.00      21.00168
# 4  Africa  Algeria  Algiers    5            63.8        17.67      17.66808

# %%
tricet = teploty[teploty["AvgTempCels"]>30]
tricet
# Out:
#                                  Region     Country             City  Day  \
# 421                              Africa  Mauritania       Nouakchott    2
# 430                              Africa  Mauritania       Nouakchott   11
# 510                              Africa     Nigeria           Niamey    1
# 526                              Africa     Nigeria           Niamey   17
# 527                              Africa     Nigeria           Niamey   18
# 528                              Africa     Nigeria           Niamey   19
# 930                                Asia       India  Bombay (Mumbai)    1
# 931                                Asia       India  Bombay (Mumbai)    2
# 935                                Asia       India  Bombay (Mumbai)    6
# 1247                               Asia        Laos        Vientiane   18
# 3990  South/Central America & Carribean       Haiti   Port au Prince    1
# 4111  South/Central America & Carribean    Suriname       Paramaribo    2
#
# ...

# %%
teploty15evropa =teploty [(teploty["AvgTempCels"]>15)& (teploty["Region"] == "Europe")]

# %%
teploty15evropa
# Out:
#       Region   Country       City  Day  AvgTemperature  AvgTempCels  \
# 1932  Europe   Albania     Tirana   13            60.3        15.72
# 2221  Europe    France   Bordeaux    2            59.2        15.11
# 2402  Europe     Italy       Rome    3            62.2        16.78
# 2404  Europe     Italy       Rome    5            60.4        15.78
# 2424  Europe     Italy       Rome   25            59.3        15.17
# 2580  Europe  Portugal     Lisbon    1            62.5        16.94
# 2581  Europe  Portugal     Lisbon    2            63.2        17.33
# 2582  Europe  Portugal     Lisbon    3            61.1        16.17
# 2583  Europe  Portugal     Lisbon    4            61.6        16.44
# 2590  Europe  Portugal     Lisbon   11            59.1        15.06
# 2592  Europe  Portugal     Lisbon   13            59.3        15.17
# 2602  Europe  Portugal     Lisbon   23            64.2        17.89
# 2603  Europe  Portugal     Lisbon   24            62.6        17.00
# ...

# %%
extremni2 = teploty[(teploty["AvgTempCels"]< -10) | (teploty["AvgTempCels"]> 30)]
extremni2
# Out:
#              Region   Country         City  Day  AvgTemperature  AvgTempCels  \
# 168          Africa  Ethiopia  Addis Ababa   19           -99.0       -72.78
# 212          Africa    Gambia       Banjul    3           -99.0       -72.78
# 213          Africa    Gambia       Banjul    4           -99.0       -72.78
# 214          Africa    Gambia       Banjul    5           -99.0       -72.78
# 215          Africa    Gambia       Banjul    6           -99.0       -72.78
# ...             ...       ...          ...  ...             ...          ...
# 6455  North America        US  Great Falls    6             7.5       -13.61
# 6485  North America        US       Helena    6            13.1       -10.50
# 6486  North America        US       Helena    7             8.7       -12.94
# 7088  North America        US        Fargo    9            12.7       -10.72
# 7089  North America        US        Fargo   10            13.1       -10.50
#
#       AvgTempCels2
# 168      -72.78360
# ...

# %%
teploty13 = teploty[teploty["Day"]== 13]
teploty13
# Out:
#              Region                   Country         City  Day  \
# 12           Africa                   Algeria      Algiers   13
# 42           Africa                     Benin      Cotonou   13
# 72           Africa  Central African Republic       Bangui   13
# 102          Africa                     Congo  Brazzaville   13
# 132          Africa                     Egypt        Cairo   13
# ...             ...                       ...          ...  ...
# 8652  North America                        US    Green Bay   13
# 8682  North America                        US      Madison   13
# 8712  North America                        US    Milwaukee   13
# 8742  North America                        US       Casper   13
# 8772  North America                        US     Cheyenne   13
#
#       AvgTemperature  AvgTempCels  AvgTempCels2
# 12              54.1        12.28      12.27876
# 42              84.1        28.94      28.94676
# 72              79.0        26.11      26.11320
# ...

# %%
teploty13us = teploty [(teploty["Day"]==13)&(teploty["Country"]=="US")]
teploty13us
# Out:
#              Region Country        City  Day  AvgTemperature  AvgTempCels  \
# 4212  North America      US  Birmingham   13            54.8        12.67
# 4242  North America      US  Huntsville   13            52.5        11.39
# 4272  North America      US      Mobile   13            61.6        16.44
# 4302  North America      US  Montgomery   13            55.1        12.83
# 4332  North America      US   Anchorage   13            16.2        -8.78
# ...             ...     ...         ...  ...             ...          ...
# 8652  North America      US   Green Bay   13            32.6         0.33
# 8682  North America      US     Madison   13            30.0        -1.11
# 8712  North America      US   Milwaukee   13            36.8         2.67
# 8742  North America      US      Casper   13            48.1         8.94
# 8772  North America      US    Cheyenne   13            45.7         7.61
#
#       AvgTempCels2
# 4212      12.66768
# 4242      11.38980
# ...

# %%
dotaz = teploty13us[(teploty13us["City"]== "Washington")|(teploty13us["City"]== "Philadelphia")]

# %%
dotaz
# Out:
#              Region Country          City  Day  AvgTemperature  AvgTempCels  \
# 4872  North America      US    Washington   13            45.2         7.33
# 4902  North America      US    Washington   13            45.2         7.33
# 7572  North America      US  Philadelphia   13            41.7         5.39
#
#       AvgTempCels2
# 4872       7.33392
# 4902       7.33392
# 7572       5.38932
