# %% [markdown]
# **Úkol 10 - Zaměstnanci a projekty**

# %% [markdown]
# ***Zadání 1***

# %%
import pandas

# %% [markdown]
# * Načtení a přidání města

# %%
praha = pandas.read_csv("zam_praha.csv")
plzen = pandas.read_csv("zam_plzeň.csv")
liberec = pandas.read_csv("zam_liberec.csv")

# %%
praha["mesto"] = "Praha"
plzen["mesto"] = "Plzen"
liberec["mesto"] = "Liberec"

# %% [markdown]
# * Spojení tabulek

# %%
zamestnanci = pandas.concat([praha, plzen, liberec], ignore_index=True)

# %% [markdown]
# * Platy

# %%
platy = pandas.read_csv("platy_2021_02.csv")

# %% [markdown]
# * Propojení

# %% [markdown]
# 1) Všichni zaměstnanci

# %%
zamestnancisplaty = pandas.merge(zamestnanci, platy, on=["cislo_zamestnance"], how="left")

# %%
byvalizamestnanci = zamestnancisplaty[zamestnancisplaty["plat"].isna()]

# %%
byvalizamestnanci.to_csv("byvalizamestnanci.csv", index=False)

# %%
pocetbyvalych = byvalizamestnanci.shape[0]

# %%
pocetbyvalych
# Out:
# 13

# %% [markdown]
# 2) Současní zaměstnanci

# %%
soucasnizamestnancisplaty = pandas.merge(zamestnanci, platy, on=["cislo_zamestnance"])

# %% [markdown]
# * Průměrné platy

# %%
soucasnizamestnancisplaty.groupby("mesto")["plat"].mean()
# Out:
# mesto
# Liberec    43775.000000
# Plzen      44792.857143
# Praha      43295.238095
# Name: plat, dtype: float64

# %% [markdown]
# ***Zadání 2***

# %%
vykazy = pandas.read_csv("vykazy.csv")

# %%
vykazy.groupby("project")["hours"].sum()
# Out:
# project
# F30    21.5
# JL9     2.1
# TE1    16.0
# W05    30.5
# YLI    31.0
# Name: hours, dtype: float64

# %% [markdown]
# ***Bonus 2***

# %%
vykazyupravene = vykazy.rename(columns=({"emloyee_id":"cislo_zamestnance", "project":"projekt"}))

# %%
spojeny = pandas.merge(soucasnizamestnancisplaty, vykazyupravene, on=["cislo_zamestnance"], how="left")

# %%
spojeny
# Out:
#           jmeno    prijimeni   telefonni_cislo  cislo_zamestnance    mesto  \
# 0         Brian         Hall  +421 949 656 098                 30    Praha
# 1         Marta     Kolářová       730 456 163                 32    Praha
# 2          John      Moravec       725 092 179                 33    Praha
# 3      Dominika      Kopecká       722 747 626                 34    Praha
# 4      Dominika      Kopecká       722 747 626                 34    Praha
# 5        Milada    Hernandez       773 373 704                 38    Praha
# 6     Catherine       Bender       604 068 460                 40    Praha
# 7     Catherine       Bender       604 068 460                 40    Praha
# 8          Olga      Němcová  +421 914 172 243                 41    Praha
# 9       Jeffrey      Šťastný       607 628 821                 44    Praha
# 10       Kamila       Říhová  +421 948 396 069                 47    Praha
# 11       Kamila       Říhová  +421 948 396 069                 47    Praha
# 12      Jaromír       Miller  +421 912 615 902                 49    Praha
# 13  Christopher        Zeman  +421 948 150 084                 51    Praha
# 14      Jeffrey     Pospíšil  +421 55 491 6940                 56    Praha
# 15     Ladislav       Blažek  +421 910 274 975                 57    Praha
# 16      William    Alexander  +421 949 106 724                 63    Praha
# 17     Kimberly         Bass  +421 912 169 840                 64    Praha
# 18        Luděk       Bartoš  +421 940 700 326                 69    Praha
# 19       Dillon        Black       734 300 978                 70    Praha
# 20        Steve        Šimek       604 966 101                 74    Praha
# 21      Theresa     Kučerová  +421 48 528 0081                 76    Praha
# 22        Marta       Butler  +421 944 196 827                 78    Praha
# 23     Samantha    Kadlecová  +421 904 841 543                 80    Praha
# 24        Stacy  Pospíšilová       727 293 880                  3    Plzen
# 25        Matěj         Král       770 787 377                  6    Plzen
# 26       Amanda       Wilson  +421 52 656 7231                  7    Plzen
# 27        Angel       Wilson  +421 52 135 2491                  8    Plzen
# 28        Radim      Kopecký  +421 917 371 226                 16    Plzen
# 29     Miroslav         Reed       774 829 074                 18    Plzen
# 30       Emilie       Powell       731 380 539                 21    Plzen
# 31       Nikola         Wade       726 763 154                 22    Plzen
# 32    Katherine         Reed       726 214 968                 23    Plzen
# 33        Kayla     Urbanová       737 772 985                 24    Plzen
# 34        Roman       Moreno       722 284 985                 26    Plzen
# 35     Bohumila        Smith       608 121 912                 27    Plzen
# 36      Blažena        Smith  +421 51 828 2591                 28    Plzen
# 37      Phillip         Malý       731 594 560                 29    Plzen
# 38         Nela      Šťastná       728 454 176                 83  Liberec
# 39      Heather      Marková       604 404 522                 84  Liberec
# 40       Krista  Procházková  +421 50 444 5544                 85  Liberec
# 41    Ladislava    Blackwell  +421 913 487 200                 87  Liberec
# 42         Dana        Reyes  +421 904 153 942                 90  Liberec
# 43        Vasyl       Veselý       603 759 413                 92  Liberec
# 44        Randy       Veselý       777 149 125                 95  Liberec
# 45       Audrey        Allen  +421 908 839 506                 96  Liberec
#
#        plat        date  hours projekt
# 0   33500.0  2021-02-01    4.4     W05
# 1   53000.0         NaN    NaN     NaN
# 2   38400.0         NaN    NaN     NaN
# 3   36800.0  2021-02-01    2.2     YLI
# 4   36800.0  2021-02-03    2.6     YLI
# 5   32600.0         NaN    NaN     NaN
# 6   32800.0  2021-02-02    3.1     YLI
# 7   32800.0  2021-02-03    5.5     W05
# 8   49300.0         NaN    NaN     NaN
# 9   52000.0  2021-02-02    2.4     YLI
# 10  40700.0  2021-02-02    2.6     W05
# 11  40700.0  2021-02-03    2.8     TE1
# 12  58400.0         NaN    NaN     NaN
# 13  37100.0         NaN    NaN     NaN
# 14  39300.0  2021-02-02    5.6     F30
# 15  36800.0  2021-02-03    5.2     W05
# 16  31400.0         NaN    NaN     NaN
# 17  36900.0         NaN    NaN     NaN
# 18  32600.0         NaN    NaN     NaN
# 19  52600.0  2021-02-01    3.4     W05
# 20  49300.0         NaN    NaN     NaN
# 21  55400.0         NaN    NaN     NaN
# 22  52600.0         NaN    NaN     NaN
# 23  57700.0         NaN    NaN     NaN
# 24  54900.0  2021-02-01    5.2     F30
# 25  54800.0         NaN    NaN     NaN
# 26  36400.0         NaN    NaN     NaN
# 27  47900.0         NaN    NaN     NaN
# 28  34200.0         NaN    NaN     NaN
# 29  35400.0  2021-02-03    2.6     F30
# 30  54200.0         NaN    NaN     NaN
# 31  34400.0         NaN    NaN     NaN
# 32  39000.0         NaN    NaN     NaN
# 33  44200.0         NaN    NaN     NaN
# 34  59600.0         NaN    NaN     NaN
# 35  45100.0         NaN    NaN     NaN
# 36  38100.0         NaN    NaN     NaN
# 37  48900.0         NaN    NaN     NaN
# 38  46500.0  2021-02-01    4.1     TE1
# 39  38600.0  2021-02-01    2.7     YLI
# 40  44200.0         NaN    NaN     NaN
# 41  49900.0  2021-02-03    2.1     TE1
# 42  41100.0         NaN    NaN     NaN
# 43  48100.0  2021-02-01    5.4     W05
# 44  31600.0         NaN    NaN     NaN
# 45  50200.0  2021-02-03    3.7     YLI
